# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\raush\\OneDrive\\Desktop\\All Project\\postings.csv")

# %%
df.shape
# Out:
# (123849, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123849 entries, 0 to 123848
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   job_id                      123849 non-null  int64
#  1   company_name                122130 non-null  object
#  2   title                       123849 non-null  object
#  3   description                 123842 non-null  object
#  4   max_salary                  29793 non-null   float64
#  5   pay_period                  36073 non-null   object
#  6   location                    123849 non-null  object
#  7   company_id                  122132 non-null  float64
#  8   views                       122160 non-null  float64
#  9   med_salary                  6280 non-null    float64
#  10  min_salary                  29793 non-null   float64
#  11  formatted_work_type         123849 non-null  object
# ...

# %%
# First 60000 rows
df.iloc[:60000].to_csv("part1.csv", index=False)

# Remaining rows
df.iloc[60000:].to_csv("part2.csv", index=False)

# %%
df.dtypes
# Out:
# job_id                          int64
# company_name                   object
# title                          object
# description                    object
# max_salary                    float64
# pay_period                     object
# location                       object
# company_id                    float64
# views                         float64
# med_salary                    float64
# min_salary                    float64
# formatted_work_type            object
# applies                       float64
# original_listed_time          float64
# remote_allowed                float64
# job_posting_url                object
# application_url                object
# application_type               object
# expiry                        float64
# closed_time                   float64
# formatted_experience_level     object
# skills_desc                    object
# listed_time                   float64
# posting_domain                 object
# sponsored                       int64
# ...

# %%
df.head(5)
# Out:
#      job_id            company_name  \
# 0    921716   Corcoran Sawyer Smith
# 1   1829192                     NaN
# 2  10998357  The National Exemplar
# 3  23221523  Abrams Fensterman, LLP
# 4  35982263                     NaN
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                  Mental Health Therapist/Counselor
# 2                        Assitant Restaurant Manager
# 3  Senior Elder Law / Trusts and Estates Associat...
# 4                                 Service Technician
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
# 2  The National Exemplar is accepting application...     65000.0     YEARLY
# 3  Senior Associate Attorney - Elder Law / Trusts...    175000.0     YEARLY
# ...

# %%
df.tail(5)
# Out:
#             job_id                     company_name  \
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                title  \
# 123844              Title IX/Investigations Attorney
# 123845  Staff Software Engineer, ML Serving Platform
# 123846          Account Executive, Oregon/Washington
# 123847                  Business Development Manager
# 123848             Marketing Social Media Specialist
#
#                                               description  max_salary  \
# 123844  Our Walnut Creek office is currently seeking a...    195000.0
# 123845  About Pinterest:\n\nMillions of people across ...         NaN
# 123846  Company Overview\n\nEPS Learning is a leading ...         NaN
# ...

# %%
df.isnull().sum()
# Out:
# job_id                             0
# company_name                    1719
# title                              0
# description                        7
# max_salary                     94056
# pay_period                     87776
# location                           0
# company_id                      1717
# views                           1689
# med_salary                    117569
# min_salary                     94056
# formatted_work_type                0
# applies                       100529
# original_listed_time               0
# remote_allowed                108603
# job_posting_url                    0
# application_url                36665
# application_type                   0
# expiry                             0
# closed_time                   122776
# formatted_experience_level     29409
# skills_desc                   121410
# listed_time                        0
# posting_domain                 39968
# sponsored                          0
# ...

# %%
df = df.dropna(subset=['company_name'])
print("After:", df.shape )
# Out:
# After: (122130, 31)

# %%
df = df.dropna(subset=['max_salary'])
print("After:",df.shape)
# Out:
# After: (29338, 31)

# %%
df.shape
# Out:
# (29338, 31)

# %%
df['company_name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['max_salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (29338, 31)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("clean_postings.csv", index=False)

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.aws',
#  '.bash_history',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.cursor',
#  '.eclipse',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.Ld9VirtualBox',
#  '.m2',
#  '.matplotlib',
#  '.p2',
#  '.python_history',
#  '.redhat',
#  '.ssh',
#  '.trae',
#  '.trae-aicc',
#  '.VirtualBox',
#  '.virtual_documents',
#  '.vscode',
#  '7168.f5129f48620a03126642.css',
#  'anaconda3',
#  'api.js.download',
#  'app.css',
#  'app.js.download',
#  'AppData',
#  'Application Data',
#  'beecoder_website',
#  'bundle.js.download',
#  'cb=gapi.loaded_0',
#  'clean_postings.csv',
#  'client',
#  'configuration-Office2019Enterprise.xml',
#  'configuration-Office2021Enterprise.xml',
#  'configuration-Office365-x64.xml',
#  'configuration-Office365-x86.xml',
#  'Contacts',
#  'Cookies',
#  'css',
#  'css2',
#  'css2(1)',
#  'daaa.py',
#  'dd_jdbc_suite_console_install.log',
#  'Documents',
#  'Downloads',
# ...

# %%
df.isnull().sum()
# Out:
# job_id                            0
# company_name                      0
# title                             0
# description                       1
# max_salary                        0
# pay_period                        0
# location                          0
# company_id                        0
# views                           424
# med_salary                    29338
# min_salary                        0
# formatted_work_type               0
# applies                       21589
# original_listed_time              0
# remote_allowed                25117
# job_posting_url                   0
# application_url               11644
# application_type                  0
# expiry                            0
# closed_time                   29207
# formatted_experience_level     6336
# skills_desc                   29137
# listed_time                       0
# posting_domain                13078
# sponsored                         0
# work_type                         0
# ...
